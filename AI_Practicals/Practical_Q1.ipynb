# %%
import os
import platform
from datetime import datetime

os_info = f"{platform.system()} {platform.release()}"
timestamp = datetime.now().strftime("%d-%m-%Y %H:%M:%S")

print(f"Current OS: {os_info}")
print(f"Log Timestamp: {timestamp}")
# Out:
# Current OS: Linux 6.17.0-22-generic
# Log Timestamp: 24-01-2026 10:03:47

# %% [markdown]
# # Experiment 1: Breadth First Search (BFS) and Depth First Search (DFS)
# **Objective:** Implement BFS and DFS algorithms to traverse a graph.
#
# **Problem Statement:** # Graph traversal is the process of visiting all nodes in a graph.
# 1. **BFS:** Uses a **Queue** (FIFO) to explore neighbors level-by-level. It is optimal for finding the shortest path in unweighted graphs.
# 2. **DFS:** Uses a **Stack** (LIFO) or recursion to explore as far as possible along each branch before backtracking.

# %%
from collections import deque

class Graph:
    def __init__(self):
        self.adj_list = {}

    def add_edge(self, u, v):
        if u not in self.adj_list:
            self.adj_list[u] = []
        if v not in self.adj_list:
            self.adj_list[v] = []
        self.adj_list[u].append(v)
        self.adj_list[v].append(u)  # For Undirected Graph

    def bfs(self, start_node):
        visited = set()
        queue = deque([start_node])
        visited.add(start_node)
        result = []

        print(f"Starting BFS from node {start_node}:")
        while queue:
            vertex = queue.popleft()
            result.append(vertex)

            for neighbor in self.adj_list.get(vertex, []):
                if neighbor not in visited:
                    visited.add(neighbor)
                    queue.append(neighbor)
        return result

    def dfs(self, start_node):
        visited = set()
        result = []

        def dfs_recursive(node):
            visited.add(node)
            result.append(node)
            for neighbor in self.adj_list.get(node, []):
                if neighbor not in visited:
                    dfs_recursive(neighbor)
        
        print(f"Starting DFS from node {start_node}:")
        dfs_recursive(start_node)
        return result

# --- Main Execution ---
g = Graph()
# Creating a sample graph
#      0
#     / \
#    1   2
#   / \   \
#  3   4   5
g.add_edge(0, 1)
g.add_edge(0, 2)
g.add_edge(1, 3)
g.add_edge(1, 4)
g.add_edge(2, 5)

bfs_res = g.bfs(0)
print("BFS Traversal:", bfs_res)

dfs_res = g.dfs(0)
print("DFS Traversal:", dfs_res)
# Out:
# Starting BFS from node 0:
# BFS Traversal: [0, 1, 2, 3, 4, 5]
# Starting DFS from node 0:
# DFS Traversal: [0, 1, 3, 4, 2, 5]
